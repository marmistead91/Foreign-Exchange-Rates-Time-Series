# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re

# %%
html_page = requests.get('https://www.federalreserve.gov/releases/H10/default.htm') # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
webpage = soup.findAll('div', class_ ='col-xs-1')
webpage
# Out:
# [<div class="col-xs-1"><a href="current">01*</a></div>,
#  <div class="col-xs-1"><a href="20200504">04</a></div>,
#  <div class="col-xs-1"><a href="20200511">11</a></div>,
#  <div class="col-xs-1"><a href="20200519">18</a></div>,
#  <div class="col-xs-1"><a href="20200526">26</a></div>,
#  <div class="col-xs-1"><a href="20200406">06</a></div>,
#  <div class="col-xs-1"><a href="20200413">13</a></div>,
#  <div class="col-xs-1"><a href="20200420">20</a></div>,
#  <div class="col-xs-1"><a href="20200427">27</a></div>,
#  <div class="col-xs-1"><a href="20200302">02</a></div>,
#  <div class="col-xs-1"><a href="20200309">09</a></div>,
#  <div class="col-xs-1"><a href="20200316">16</a></div>,
#  <div class="col-xs-1"><a href="20200323">23</a></div>,
#  <div class="col-xs-1"><a href="20200330">30</a></div>,
#  <div class="col-xs-1"><a href="20200203">03</a></div>,
#  <div class="col-xs-1"><a href="20200210">10</a></div>,
#  <div class="col-xs-1"><a href="20200218">18</a></div>,
# ...

# %%
type(webpage)
# Out:
# bs4.element.ResultSet

# %%
webpage[0].find('a').attrs['href']
# Out:
# 'current'

# %%
pages= [h3.find('a').attrs['href'] for h3 in webpage]
pages
# Out:
# ['current',
#  '20200504',
#  '20200511',
#  '20200519',
#  '20200526',
#  '20200406',
#  '20200413',
#  '20200420',
#  '20200427',
#  '20200302',
#  '20200309',
#  '20200316',
#  '20200323',
#  '20200330',
#  '20200203',
#  '20200210',
#  '20200218',
#  '20200224',
#  '20200106',
#  '20200113',
#  '20200120',
#  '20200127',
#  '20191202',
#  '20191209',
#  '20191216',
#  '20191223',
#  '20191230',
#  '20191104',
#  '20191111',
#  '20191118',
#  '20191125',
#  '20191007',
#  '20191015',
#  '20191021',
#  '20191028',
#  '20190903',
#  '20190909',
#  '20190916',
#  '20190923',
#  '20190930',
#  '20190805',
#  '20190812',
#  '20190819',
#  '20190827',
#  '20190701',
#  '20190708',
#  '20190715',
#  '20190722',
#  '20190729',
#  '20190603',
#  '20190610',
#  '20190617',
#  '20190624',
#  '20190506',
#  '20190513',
#  '20190520',
#  '20190527',
#  '20190401',
#  '20190408',
#  '20190415',
#  '20190422',
#  '20190429',
#  '20190304',
#  '20190311',
#  '20190318',
#  '20190325',
# ...

# %%
len(pages)
# Out:
# 1146

# %%
for i in pages:
    if len(i)!=8:
        pages.remove(i)
len(pages)
# Out:
# 1084

# %%
pages.sort()
len(pages)
pages
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '19960712/',
#  '19960726/',
#  '19960805/',
#  '19960819/',
#  '19960830/',
#  '19960909/',
#  '19960920/',
#  '19961004/',
#  '19961021/',
#  '19961104/',
#  '19961118/',
#  '19961209/',
#  '19961223/',
#  '19970113/',
#  '19970127/',
#  '19970210',
#  '19970224/',
#  '19970303/',
#  '19970317/',
#  '19970331/',
#  '19970407/',
#  '19970421/',
#  '19970505/',
#  '19970519/',
#  '19970609/',
#  '19970623/',
#  '19970714/',
#  '19970728/',
#  '19970811/',
#  '19970825/',
#  '19970902/',
#  '19970915/',
#  '19970929/',
#  '19971006/',
#  '19971020/',
#  '19971103/',
#  '19971117/',
#  '19971208/',
#  '19971222/',
#  '19980105',
#  '19980112',
#  '19980120',
#  '19980126',
#  '19980202',
#  '19980209',
#  '19980217',
#  '19980223',
#  '19980302',
#  '19980309',
#  '19980316',
#  '19980323',
#  '19980330',
#  '19980406',
#  '19980413',
#  '19980420',
#  '19980427',
# ...

# %%
x=pages[0:5]
x
# Out:
# ['20200504', '20200511', '20200519', '20200526', '20200406']

# %%
for i in x:
    print(f'https://ww.feeralreserve.gov/releases/H10/{i}')
# Out:
# https://ww.feeralreserve.gov/releases/H10/20200504
# https://ww.feeralreserve.gov/releases/H10/20200511
# https://ww.feeralreserve.gov/releases/H10/20200519
# https://ww.feeralreserve.gov/releases/H10/20200526
# https://ww.feeralreserve.gov/releases/H10/20200406

# %%
y= 'https://www.federalreserve.gov/releases/H10/20200504/'

# %%
html = requests.get(y) # Make a get request to retrieve the page
week = BeautifulSoup(html.content, 'lxml')

# %%
table=week.table

# %%
table
# Out:
# <table border="0" cellpadding="0" cellspacing="0" class="statistics">
# <thead>
# <tr>
# <th colspan="1" id="a1">COUNTRY</th>
# <th id="a2">CURRENCY</th>
# <th id="a3"> Apr. 27 </th>
# <th id="a4"> Apr. 28 </th>
# <th id="a5"> Apr. 29 </th>
# <th id="a6"> Apr. 30 </th>
# <th id="a7"> May  1  </th>
# </tr>
# </thead>
# <tr>
# <th headers="a1" id="r1"> *AUSTRALIA     </th>
# <td headers="a2 a1 r1">DOLLAR     </td>
# <td headers="a3 a1 r1">   0.6460</td>
# <td headers="a4 a1 r1">   0.6499</td>
# <td headers="a5 a1 r1">   0.6536</td>
# <td headers="a6 a1 r1">   0.6523</td>
# <td headers="a7 a1 r1">   0.6424</td>
# </tr>
# <tr>
# <th headers="a1" id="r1">  BRAZIL        </th>
# <td headers="a2 a1 r1">REAL       </td>
# <td headers="a3 a1 r1">   5.6741</td>
# <td headers="a4 a1 r1">   5.5646</td>
# <td headers="a5 a1 r1">   5.3923</td>
# <td headers="a6 a1 r1">   5.4296</td>
# <td headers="a7 a1 r1">   5.4858</td>
# </tr>
# <tr>
# <th headers="a1" id="r1">  CANADA        </th>
# ...

# %%
table_rows=table.find_all('tr')

for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['DOLLAR     ', '   0.6460', '   0.6499', '   0.6536', '   0.6523', '   0.6424']
# ['REAL       ', '   5.6741', '   5.5646', '   5.3923', '   5.4296', '   5.4858']
# ['DOLLAR     ', '   1.4042', '   1.3992', '   1.3936', '   1.3911', '   1.4102']
# ['YUAN       ', '   7.0848', '   7.0776', '   7.0755', '   7.0622', '   7.0622']
# ['KRONE      ', '   6.8858', '   6.8802', '   6.8717', '   6.8233', '   6.7828']
# ['EURO       ', '   1.0829', '   1.0836', '   1.0853', '   1.0934', '   1.0998']
# ['DOLLAR     ', '   7.7499', '   7.7498', '   7.7503', '   7.7514', '   7.7517']
# ['RUPEE      ', '  76.2300', '  75.9600', '  75.4500', '  75.0800', '  75.7500']
# ['YEN        ', ' 107.2200', ' 106.8300', ' 106.6700', ' 106.9400', ' 106.7600']
# ['RINGGIT    ', '   4.3500', '   4.3600', '   4.3410', '   4.3004', '   4.3004']
# ['PESO       ', '  24.8320', '  24.3940', '  23.9270', '  23.9790', '  24.8066']
# ...

# %%
for tr in table_rows:
    th = tr.find_all('th')
    row = [i.text for i in th]
    print(row)
# Out:
# ['COUNTRY', 'CURRENCY', ' Apr. 27 ', ' Apr. 28 ', ' Apr. 29 ', ' Apr. 30 ', ' May  1  ']
# [' *AUSTRALIA     ']
# ['  BRAZIL        ']
# ['  CANADA        ']
# ['  CHINA, P.R.   ']
# ['  DENMARK       ']
# [' *EMU MEMBERS   ']
# ['  HONG KONG     ']
# ['  INDIA         ']
# ['  JAPAN         ']
# ['  MALAYSIA      ']
# ['  MEXICO        ']
# [' *NEW ZEALAND   ']
# ['  NORWAY        ']
# ['  SINGAPORE     ']
# ['  SOUTH AFRICA  ']
# ['  SOUTH KOREA   ']
# ['  SRI LANKA     ']
# ['  SWEDEN        ']
# ['  SWITZERLAND   ']
# ['  TAIWAN        ']
# ['  THAILAND      ']
# [' *UNITED KINGDOM']
# ['  VENEZUELA     ']
# ['1) BROAD                    ']
# ['2) AFE                      ']
# ['3) EME                      ']

# %%
df = pd.read_html(str(table), index_col='COUNTRY')
df = df[0].dropna(axis=0, thresh=4)
df
# Out:
#                   CURRENCY      Apr. 27      Apr. 28      Apr. 29  \
# COUNTRY
# *AUSTRALIA          DOLLAR       0.6460       0.6499       0.6536
# BRAZIL                REAL       5.6741       5.5646       5.3923
# CANADA              DOLLAR       1.4042       1.3992       1.3936
# CHINA, P.R.           YUAN       7.0848       7.0776       7.0755
# DENMARK              KRONE       6.8858       6.8802       6.8717
# *EMU MEMBERS          EURO       1.0829       1.0836       1.0853
# HONG KONG           DOLLAR       7.7499       7.7498       7.7503
# INDIA                RUPEE      76.2300      75.9600      75.4500
# JAPAN                  YEN     107.2200     106.8300     106.6700
# MALAYSIA           RINGGIT       4.3500       4.3600       4.3410
# MEXICO                PESO      24.8320      24.3940      23.9270
# *NEW ZEALAND        DOLLAR       0.6054       0.6063       0.6104
# NORWAY               KRONE      10.5772      10.4079      10.3548
# ...

# %%
html2 = requests.get('https://www.federalreserve.gov/releases/H10/20200210/') # Make a get request to retrieve the page
week2 = BeautifulSoup(html2.content, 'lxml')
table2=week2.table

# %%
table2
# Out:
# <table border="0" cellpadding="0" cellspacing="0" class="statistics">
# <thead>
# <tr>
# <th colspan="1" id="a1">COUNTRY</th>
# <th id="a2">CURRENCY</th>
# <th id="a3"> Feb. 3  </th>
# <th id="a4"> Feb. 4  </th>
# <th id="a5"> Feb. 5  </th>
# <th id="a6"> Feb. 6  </th>
# <th id="a7"> Feb. 7  </th>
# </tr>
# </thead>
# <tr>
# <th headers="a1" id="r1"> *AUSTRALIA     </th>
# <td headers="a2 a1 r1">DOLLAR     </td>
# <td headers="a3 a1 r1">   0.6688</td>
# <td headers="a4 a1 r1">   0.6732</td>
# <td headers="a5 a1 r1">   0.6748</td>
# <td headers="a6 a1 r1">   0.6738</td>
# <td headers="a7 a1 r1">   0.6679</td>
# </tr>
# <tr>
# <th headers="a1" id="r1">  BRAZIL        </th>
# <td headers="a2 a1 r1">REAL       </td>
# <td headers="a3 a1 r1">   4.2411</td>
# <td headers="a4 a1 r1">   4.2405</td>
# <td headers="a5 a1 r1">   4.2567</td>
# <td headers="a6 a1 r1">   4.2694</td>
# <td headers="a7 a1 r1">   4.3126</td>
# </tr>
# <tr>
# <th headers="a1" id="r1">  CANADA        </th>
# ...

# %%
df2=pd.read_html(str(table2), index_col='COUNTRY')
df2=df2[0].dropna(axis=0, thresh=4)
df2
# Out:
#                   CURRENCY      Feb. 3      Feb. 4      Feb. 5      Feb. 6  \
# COUNTRY
# *AUSTRALIA          DOLLAR      0.6688      0.6732      0.6748      0.6738
# BRAZIL                REAL      4.2411      4.2405      4.2567      4.2694
# CANADA              DOLLAR      1.3295      1.3266      1.3294      1.3292
# CHINA, P.R.           YUAN      7.0208      6.9979      6.9720      6.9694
# DENMARK              KRONE      6.7549      6.7665      6.7670      6.8062
# *EMU MEMBERS          EURO      1.1062      1.1043      1.1006      1.0979
# HONG KONG           DOLLAR      7.7678      7.7652      7.7640      7.7630
# INDIA                RUPEE     71.3200     71.1100     71.1900     71.1900
# JAPAN                  YEN    108.5900    109.4100    109.7400    109.8900
# MALAYSIA           RINGGIT      4.1140      4.1090      4.1155      4.1225
# MEXICO                PESO     18.7900     18.6760     18.6200     18.6700
# ...

# %%
result=pd.concat([df,df2], axis=1, join='inner')
result
# Out:
#                   CURRENCY      Apr. 27      Apr. 28      Apr. 29  \
# COUNTRY
# *AUSTRALIA          DOLLAR       0.6460       0.6499       0.6536
# BRAZIL                REAL       5.6741       5.5646       5.3923
# CANADA              DOLLAR       1.4042       1.3992       1.3936
# CHINA, P.R.           YUAN       7.0848       7.0776       7.0755
# DENMARK              KRONE       6.8858       6.8802       6.8717
# *EMU MEMBERS          EURO       1.0829       1.0836       1.0853
# HONG KONG           DOLLAR       7.7499       7.7498       7.7503
# INDIA                RUPEE      76.2300      75.9600      75.4500
# JAPAN                  YEN     107.2200     106.8300     106.6700
# MALAYSIA           RINGGIT       4.3500       4.3600       4.3410
# MEXICO                PESO      24.8320      24.3940      23.9270
# *NEW ZEALAND        DOLLAR       0.6054       0.6063       0.6104
# NORWAY               KRONE      10.5772      10.4079      10.3548
# ...

# %%
result=pd.concat([result,df2], axis=1)
result
# Out:
#                   CURRENCY      Apr. 27      Apr. 28      Apr. 29  \
# COUNTRY
# *AUSTRALIA          DOLLAR       0.6460       0.6499       0.6536
# BRAZIL                REAL       5.6741       5.5646       5.3923
# CANADA              DOLLAR       1.4042       1.3992       1.3936
# CHINA, P.R.           YUAN       7.0848       7.0776       7.0755
# DENMARK              KRONE       6.8858       6.8802       6.8717
# *EMU MEMBERS          EURO       1.0829       1.0836       1.0853
# HONG KONG           DOLLAR       7.7499       7.7498       7.7503
# INDIA                RUPEE      76.2300      75.9600      75.4500
# JAPAN                  YEN     107.2200     106.8300     106.6700
# MALAYSIA           RINGGIT       4.3500       4.3600       4.3410
# MEXICO                PESO      24.8320      24.3940      23.9270
# *NEW ZEALAND        DOLLAR       0.6054       0.6063       0.6104
# NORWAY               KRONE      10.5772      10.4079      10.3548
# ...

# %%
def scrap_currenies(html):
    html_page = requests.get(html)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    webpage = soup.findAll('div', class_ ='col-xs-1')
    pages= [h3.find('a').attrs['href'] for h3 in webpage]
    for i in pages:
        if len(i)!=8:
            pages.remove(i)
    pages.sort()
    for i in x:
        print(f'https://www.federalreserve.gov/releases/H10/20200210/{i}')
# Out:
#   File "<ipython-input-77-2a814f0972b5>", line 1
#     def scrap_currenies(htmls):
#                                ^
# SyntaxError: unexpected EOF while parsing
